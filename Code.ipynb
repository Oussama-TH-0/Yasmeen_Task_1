# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/employee-data/Employee 1000x.csv")
print(df.shape)
# Out:
# (10000, 8)

# %%
# file contains data for 10000 employee with 8 columns 
df.head(3) # to print the data of the first 3 employees
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female           tsharp@example.net
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
#
#                    Phone Date of birth              Job Title
# 0     (971)643-6089x9160      17-08-21  Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69     Broadcast engineer
# 2             9017807728      25-09-15       Industrial buyer

# %%
# check if we have empty cells of Null Values
null_data = df.isnull().values.any()
print(null_data)
# Out:
# False

# %%
#since we dont have any missing infomation lets start the analysis
df["Sex"].value_counts() / df.shape[0] *100
# Out:
# Sex
# Female    50.74
# Male      49.26
# Name: count, dtype: float64

# %%
title_count = df['Job Title'].value_counts().reset_index()
title_count.columns = ['Job Title', 'Count']
title_count
# Out:
#                     Job Title  Count
# 0           Film/video editor     30
# 1           Medical secretary     28
# 2          Wellsite geologist     28
# 3         Exhibition designer     27
# 4           Probation officer     27
# ..                        ...    ...
# 634         Fish farm manager      7
# 635  Waste management officer      7
# 636   Chief Financial Officer      5
# 637          Theatre director      5
# 638    Holiday representative      5
#
# [639 rows x 2 columns]

# %%
# to visualise the titles in chart we need some libraries
import seaborn as sb
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sb.barplot(data=title_count.head(20),x="Job Title",y="Count", palette='viridis')
plt.xticks(rotation=90)
plt.title('Number of Employees by Job Title')
plt.tight_layout()
plt.show()

# %% [markdown]
# #
